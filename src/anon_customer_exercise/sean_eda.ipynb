# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from anon_customer_exercise.pipeline import PipelineFactory

# %%
df = pd.read_csv('../../data/anon_cust_data.csv')
df.drop(columns='Unnamed: 0', inplace=True)
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
y = df['Churn']
X = df.drop(columns='Churn')

# %%
models = [RandomForestClassifier(random_state=42),
          LogisticRegression(),
          GradientBoostingClassifier()]
for model in models:
    pipe = PipelineFactory(X=X, y=y, model=model)
    print(pipe.classifier_report)
    print(pipe.feature_importances)
# Out:
#             RandomForestClassifier(random_state=42)
#             ======================================================
#                           precision    recall  f1-score   support
#
#           No       0.83      0.91      0.87      1036
#          Yes       0.65      0.47      0.55       373
#
#     accuracy                           0.79      1409
#    macro avg       0.74      0.69      0.71      1409
# weighted avg       0.78      0.79      0.78      1409
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 7
#       5 pipe = PipelineFactory(X=X, y=y, model=model)
#       6 print(pipe.classifier_report)
# ----> 7 print(pipe.coefficients)
#
# File ~/code/projects/ddi13/assignments/anon_customer_exercise/src/anon_customer_exercise/pipeline.py:114, in PipelineFactory.coefficients(self)
#     112     model = self.model_pipeline.named_steps['model']
#     113     cols = self.model_pipeline.named_steps['preprocess'].get_feature_names_out()
# --> 114     return pd.concat([pd.DataFrame(cols),pd.DataFrame(np.transpose(model.coef_))], axis = 1)
#     115 return None
#
# AttributeError: 'RandomForestClassifier' object has no attribute 'coef_'
